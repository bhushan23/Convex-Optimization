# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-20000,20000,1)
print(x)
# Out:
# [-20000 -19999 -19998 ...,  19997  19998  19999]

# %%
plt.plot(x**2+8)
plt.ylabel('some numbers')
for i in range(5):
    plt.
plt.show()
